# %% [markdown]
# # Data Science Tools and Ecosytem

# %% [markdown]
# In this noteboook, Data Science Tools and Ecosytem are summarized.

# %% [markdown]
# #### Objective:
# - List popular languaes for Data Science
# - List commonly used libraries used by Data Scientists
# - List Data science tools
# - Evaluating arithmetic exprssions in pythhon

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python Language
# 2. R Language
# 3. Structure Query Language

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. ggplot
# 2. pandas
# 3. Tensor Flow
# 4. Pytorch

# %% [markdown]
# | Data Science Tools |
# | -------------------|
# | R Studio |
# | Jupyter Notebook |
# | Ray |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expresions in Python

# %%
(3*4)+5
#This is a simple arithmetic expression to multiply then add integers
# Out:
# 17

# %%
200/60
#This will convert 200 minutes to hours by dividing by 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Prince Nwachukwu
